# %%
# !pip install --upgrade gensim
from gensim.models.fasttext import FastText
import numpy as np
# %tensorflow_version 1.x
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
import nltk
import re
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Bidirectional, Embedding, Dropout
from keras.callbacks import ModelCheckpoint
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/2b/e0/fa6326251692056dc880a64eb22117e03269906ba55a6864864d24ec8b4e/gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 1.3MB/s
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (1.14.5)
# Requirement already satisfied, skipping upgrade: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.2)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (1.24.3)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied, skipping upgrade: botocore<1.18.0,>=1.17.5 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (1.17.5)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Installing collected packages: gensim
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.3
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
import pandas as pd
def load_dataset(filename):
  df = pd.read_csv(filename, encoding = "utf-8",
       names = ["Sentence", "Intent"])
  intent = df["Intent"]
  unique_intent = list(set(intent))
  sentences = list(df["Sentence"])
  
  return (intent, unique_intent, sentences)

# %%
intent, unique_intent, sentences = load_dataset("/content/bank.csv")

# %%
nltk.download("punkt")
def cleaning(sentences):
  words = [] 
  for s in sentences:
    w = word_tokenize(s)
    words.append([i for i in w])     
  return words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
cleaned_words = cleaning(sentences)
print(len(cleaned_words))
print(cleaned_words[:2])  
print(len(sentences))
# Out:
# 1567
# [['நான்', '2in1', 'கணக்கில்', 'சேமிப்பது', 'எப்படி', '?'], ['2in1', 'கணக்கில்', 'நான்', 'சேமிப்பது', 'எப்படி', '?']]
# 1567

# %%
def create_tokenizer(words, filters = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~'):
  token = Tokenizer(filters = filters)
  token.fit_on_texts(words)
  return token

# %%
def max_length(words):
  return(len(max(words, key = len)))

# %%
word_tokenizer = create_tokenizer(cleaned_words)
vocab_size = len(word_tokenizer.word_index) + 1
max_length = max_length(cleaned_words)

print("Vocab Size = %d and Maximum length = %d" % (vocab_size, max_length))
# Out:
# Vocab Size = 1141 and Maximum length = 22

# %%
print(cleaned_words[0])
# Out:
# ['நான்', '2in1', 'கணக்கில்', 'சேமிப்பது', 'எப்படி', '?']

# %%
embedding_size = 300
window_size = 40
min_word = 5
down_sampling = 1e-2

# %%
ft_model = FastText(cleaned_words,
                      size=embedding_size,
                      window=window_size,
                      min_count=min_word,
                      sample=down_sampling,
                      sg=1,
                      iter=100)

# %%
print(ft_model.wv['2in1'])
word_tokenizer.word_index.items()
# Out:
# [ 3.39925736e-01  7.49238655e-02 -6.95590079e-02 -5.32058120e-01
#   2.64677424e-02 -5.34267426e-01 -2.58713096e-01  1.98973551e-01
#   2.62593955e-01  3.81210208e-01 -1.23464279e-02 -2.41077200e-01
#  -2.73910284e-01  1.77634373e-01  2.27735177e-01 -1.18934445e-01
#  -6.08478040e-02 -2.74485737e-01 -1.63209215e-02  1.55432090e-01
#   3.08730572e-01  3.34933877e-01 -3.13027054e-01 -2.59852141e-01
#   4.22765724e-02 -4.59798127e-02 -6.45569190e-02  3.23049366e-01
#   8.52603018e-02  4.60073352e-02 -3.56734484e-01  7.69669563e-02
#  -1.14356972e-01  3.02679557e-02 -2.16333643e-01 -1.37601599e-01
#  -1.62518919e-01  3.85744460e-02 -1.29629776e-01 -1.19700972e-02
ர்', 43), ('எனக்கு', 44), ('2in1', 45), ('வேண்டிய', 46), ('ஒன்றை', 47), ('புதிய', 48), ('தேவைப்படும்', 49), ('மாதாந்த', 50), ('கணக்கொன்றை', 51), ('கணக்கிற்கான', 52), ('கடனை', 53), ('குறைந்தபட்ச', 54), ('மற்றும்', 55), ('வகையின்', 56), ('வயது', 57), ('தொகை', 58), ('விற்பனை', 59), ('பெறுவது', 60), ('வேண்டுமா', 61), ('கணக்கில்', 62), ('கொள்ளலாம்', 63), ('வீடமைப்பு', 64), ('மூலம்', 65), ('cvv', 66), ('கணக்கு', 67), ('உண்டியல்கள்', 68), ('பெற்றுக்கொள்ள', 69), ('விவரங்களை', 70), ('செய்வது', 71), ('சேமிப்புக்', 72), ('எங்கு', 73), ('2', 74), ('அறிக்கைகளை', 75), ('முதலீடு', 76), ('1', 77), ('பணத்தை', 78), ('கடனட்டையை', 79), ('பெறுவதில்', 80), ('ஏற்படும்', 81), ('வர்த்தகர்கள்', 82), ('நன்மைகள்', 83), ('பெறலாம்', 84), ('பிரத்தியேக', 85), ('டிகிரி', 86), ('அட்டையில்', 87), ('debit', 88), ('திறக்க', 89), ('காப்புறுதியை', 90), ('வதிவுள்ள', 91), ('வைப்பினை', 92), ('வைப்புத்', 93), ('ஆரம்பிப்பது', 94), ('வேறு', 95), ('நாடுகளில்', 96), ('செலவுகள்', 97), ('nrfc', 98), ('ஆரம்பிப்பதற்குத்', 99), ('கூடிய', 100), ('பயன்படுத்த', 101), ('மாற்றிக்', 102), ('வட்டியை', 103), ('பணம்', 104), ('ஆரம்பிக்கத்', 105), ('பெற்று', 106), ('செயற்பாடு', 107), ('ஒரு', 108), ('atm', 109), ('கிடைக்குமா', 110), ('விபரங்களை', 111), ('வைப்பை', 112), ('வரை', 113), ('முனைக்', 114), ('ஏற்க', 115), ('மோசடியான', 116), ('பயன்படுத்தலாம்', 117), ('என', 118), ('in', 119), ('குறைந்த', 120), ('புத்தகத்தை', 121), ('யாவை', 122), ('ஒன்றின்', 123), ('தொடர்பான', 124), ('வெளிநாடுகளிலும்', 125), ('தேவை', 126), ('கருவியைப்', 127), ('பயன்படுத்தலாமா', 128), ('கொள்வதற்கு', 129), ('உண்டியல்களின்', 130), ('பெற்றுக்கொள்வது', 131), ('கிடைக்கும்', 132), ('repos', 133), ('இடம்பெறுகிறது', 134), ('முக்கிய', 135), ('என்பது', 136), ('காணப்பட', 137), ('கடனட்டை', 138), ('இயலுமா', 139), ('செய்யலாம்', 140), ('கொள்வது', 141), ('lc', 142), ('விண்ணப்பப்', 143), ('பாதுகாப்பு', 144), ('உத்தரவாதம்', 145), ('அன்பளிப்பு', 146), ('ஒன்றிலிருந்து', 147), ('விபரம்', 148), ('வங்கி', 149), ('பட்சத்தில்', 150), ('சொல்ல', 151), ('யாது', 152), ('பெறுவதற்கு', 153), ('account', 154), ('வைப்பிற்கு', 155), ('எதிராக', 156), ('seylan', 157), ('என்ற', 158), ('தனிப்பட்ட', 159), ('எத்தனை', 160), ('இலக்கம்', 161), ('இக்கணக்கிலிருந்து', 162), ('மீளப்', 163), ('சந்தேகிக்கும்', 164), ('கொள்வனவு', 165), ('பத்திரங்களை', 166), ('நாம்', 167), ('காலாவதியாவதற்கு', 168), ('சுயமாகவே', 169), ('முன்னர்', 170), ('பத்திரங்கள்', 171), ('வெளிநாட்டில்', 172), ('(', 173), (')', 174), ('வதிவற்ற', 175), ('அபிவிருத்தி', 176), ('வாடிக்கையாளர்', 177), ('அம்சங்கள்', 178), ('பற்றிய', 179), ('கூறுக', 180), ('பெறமுடியுமா', 181), ('தொடங்க', 182), ('முன்னதாக', 183), ('பெற்றுக்கொள்ளலாம்', 184), ('என்னுடைய', 185), ('ஆகக்குறைந்த', 186), ('ஒன்றைப்', 187), ('படிவமொன்றை', 188), ('இணைய', 189), ('பெறுமதி', 190), ('ஒன்றினால்', 191), ('நிலுவையாக', 192), ('வைப்பு', 193), ('காலாவதியாகினால்', 194), ('தகைமை', 195), ('தேவைகளுக்கு', 196), ('காப்புறுதி', 197), ('மோசடி', 198), ('எந்தெந்த', 199), ('அனுமதி', 200), ('எவ்வாறான', 201), ('வங்கிச்', 202), ('எஞ்சிய', 203), ('முதிர்ச்சிக்', 204), ('காலத்திற்கு', 205), ("''", 206), ('பெற்றுக்கொள்ளக்கூடிய', 207), ('in1', 208), ('புத்தகம்', 209), ('ஆரம்பிக்கலாம்', 210), ('வங்கிக்', 211), ('என்ட', 212), ('foreign', 213), ('பயன்கள்', 214), ('செல்லுபடியாகும்', 215), ('இலக்கத்தை', 216), ('கொண்டு', 217), ('காலம்', 218), ('தகவல்', 219), ('என்னால்', 220), ('விபரங்கள்', 221), ('குறைந்தபட்சம ...

# %%
word_index =word_tokenizer.word_index

# %%
#embedding matrix

print('preparing embedding matrix...')
words_not_found = []
nb_words = 1141

embedding_matrix = np.zeros((nb_words, embedding_size ))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = ft_model.wv[word]
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
print("sample words not found: ", words_not_found)
# Out:
# sample words not found:  []

# %%
def encoding_doc(token, words):
  return(token.texts_to_sequences(words))

# %%
#tokenizer with filter changed
output_tokenizer = create_tokenizer(unique_intent, filters = '!"#$%&()*+,-/:;<=>?@[\]^`{|}~')
encoded_output = encoding_doc(output_tokenizer, intent)
encoded_output = np.array(encoded_output).reshape(len(encoded_output), 1)
encoded_output.shape
# Out:
# (1567, 1)

# %%
def one_hot(encode):
  o = OneHotEncoder(sparse = False)
  return(o.fit_transform(encode))

# %%
output_one_hot = one_hot(encoded_output)

# %%
encoded_doc = encoding_doc(word_tokenizer, cleaned_words)

# %%
def padding_doc(encoded_doc, max_length):
  return(pad_sequences(encoded_doc, maxlen = max_length, padding = "post"))

# %%
padded_doc = padding_doc(encoded_doc, max_length)

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_Y, val_Y = train_test_split(padded_doc, output_one_hot, shuffle = True, test_size = 0.2)
print("Shape of train_X = %s and train_Y = %s" % (train_X.shape, train_Y.shape))
print("Shape of val_X = %s and val_Y = %s" % (val_X.shape, val_Y.shape))
# Out:
# Shape of train_X = (1253, 22) and train_Y = (1253, 56)
# Shape of val_X = (314, 22) and val_Y = (314, 56)

# %%
def create_model(vocab_size, max_length):
  model = Sequential()
  model.add(Embedding(nb_words, embedding_size, weights=[embedding_matrix], input_length=max_length, trainable=False))
  model.add(Bidirectional(LSTM(128)))
#   model.add(LSTM(128))
  model.add(Dense(32, activation = "relu"))
  model.add(Dropout(0.5))
  model.add(Dense(56, activation = "softmax"))
  
  return model

# %%
model = create_model(vocab_size, max_length)

model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 22, 300)           342300
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 56)                1848
# =================================================================
# Total params: 791,668
# Trainable params: 449,368
# Non-trainable params: 342,300
# _________________________________________________________________

# %%
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

hist = model.fit(train_X, train_Y, epochs = 100, batch_size = 32, validation_data = (val_X, val_Y), callbacks = [checkpoint])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1253 samples, validate on 314 samples
# Epoch 1/100
# 1253/1253 [==============================] - 9s 7ms/step - loss: 3.6406 - accuracy: 0.1173 - val_loss: 2.7318 - val_accuracy: 0.4522
#
# Epoch 00001: val_loss improved from inf to 2.73180, saving model to model.h5
# Epoch 2/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 2.5707 - accuracy: 0.3424 - val_loss: 1.7389 - val_accuracy: 0.5732
#
# Epoch 00002: val_loss improved from 2.73180 to 1.73894, saving model to model.h5
# Epoch 3/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 1.9099 - accuracy: 0.4820 - val_loss: 1.2131 - val_accuracy: 0.7389
#
# Epoch 00003: val_loss improved from 1.73894 to 1.21313, saving model to model.h5
# Epoch 4/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 1.4601 - accuracy: 0.5906 - val_loss: 0.8771 - val_accuracy: 0.8217
#
# Epoch 00004: val_loss improved from 1.21313 to 0.87712, saving model to model.h5
# Epoch 5/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 1.1912 - accuracy: 0.6664 - val_loss: 0.6466 - val_accuracy: 0.8790
#
# Epoch 00005: val_loss improved from 0.87712 to 0.64664, saving model to model.h5
# Epoch 6/100
# 1253/1253 [==============================] - 7s 5ms/step - loss: 1.0212 - accuracy: 0.7159 - val_loss: 0.4814 - val_accuracy: 0.9299
#
# Epoch 00006: val_loss improved from 0.64664 to 0.48141, saving model to model.h5
# Epoch 7/100
# 1253/1253 [==============================] - 8s 7ms/step - loss: 0.8983 - accuracy: 0.7486 - val_loss: 0.4284 - val_accuracy: 0.9204
#
# Epoch 00007: val_loss improved from 0.48141 to 0.42844, saving model to model.h5
# Epoch 8/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.7919 - accuracy: 0.7797 - val_loss: 0.4020 - val_accuracy: 0.9013
#
# Epoch 00008: val_loss improved from 0.42844 to 0.40199, saving model to model.h5
# Epoch 9/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 0.7483 - accuracy: 0.7837 - val_loss: 0.2525 - val_accuracy: 0.9554
#
# Epoch 00009: val_loss improved from 0.40199 to 0.25245, saving model to model.h5
# Epoch 10/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.6564 - accuracy: 0.8069 - val_loss: 0.2597 - val_accuracy: 0.9427
#
# Epoch 00010: val_loss did not improve from 0.25245
# Epoch 11/100
# 1253/1253 [==============================] - 7s 6ms/step - loss: 0.6065 - accuracy: 0.8125 - val_loss: 0.2044 - val_accuracy: 0.9682
#
# Epoch 00011: val_loss improved from 0.25245 to 0.20436, saving model to model.h5
# Epoch 12/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.5316 - accuracy: 0.8460 - val_loss: 0.1596 - val_accuracy: 0.9713
#
# Epoch 00012: val_loss improved from 0.20436 to 0.15961, saving model to model.h5
# Epoch 13/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.5026 - accuracy: 0.8428 - val_loss: 0.1294 - val_accuracy: 0.9745
#
# Epoch 00013: val_loss improved from 0.15961 to 0.12942, saving model to model.h5
# Epoch 14/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.4520 - accuracy: 0.8563 - val_loss: 0.1344 - val_accuracy: 0.9777
#
# Epoch 00014: val_loss did not improve from 0.12942
# Epoch 15/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.4260 - accuracy: 0.8707 - val_loss: 0.1061 - val_accuracy: 0.9841
#
# Epoch 00015: val_loss improved from 0.12942 to 0.10607, saving model to model.h5
# Epoch 16/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.4259 - accuracy: 0.8731 - val_loss: 0.1139 - val_accuracy: 0.9873
#
# Epoch 00016: val_loss did not improve from 0.10607
# Epoch 17/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 0.3841 - accuracy: 0.8819 - val_loss: 0.0962 - val_accuracy: 0.9777
#
# Epoch 00017: val_loss improved from 0.10607 to 0.09623, saving model to model.h5
# Epoch 18/100
# 1253/1253 [==============================] - 7s 5ms/step - loss: 0.4042 - accuracy: 0.8731 - val_loss: 0.0656 - val_accuracy: 0.9904
#
# Epoch 00018: val_loss improved from 0.09623 to 0.06555, saving model to model.h5
# Epoch 19/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.3710 - accuracy: 0.8843 - val_loss: 0.0737 - val_accuracy: 0.9809
#
# Epoch 00019: val_loss did not improve from 0.06555
# Epoch 20/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.3348 - accuracy: 0.8994 - val_loss: 0.0699 - val_accuracy: 0.9904
#
# Epoch 00020: val_loss did not improve from 0.06555
# Epoch 21/100
# 1253/1253 [==============================] - 7s 6ms/step - loss: 0.3139 - accuracy: 0.9042 - val_loss: 0.0800 - val_accuracy: 0.9809
#
# Epoch 00021: val_loss did not improve from 0.06555
# Epoch 22/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.3026 - accuracy: 0.8986 - val_loss: 0.0621 - val_accuracy: 0.9873
#
# Epoch 00022: val_loss improved from 0.06555 to 0.06206, saving model to model.h5
# Epoch 23/100
# 1253/1253 [==============================] - 7s 6ms/step - loss: 0.2980 - accuracy: 0.8970 - val_loss: 0.0790 - val_accuracy: 0.9809
#
# Epoch 00023: val_loss did not improve from 0.06206
# Epoch 24/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2974 - accuracy: 0.9018 - val_loss: 0.0679 - val_accuracy: 0.9873
#
# Epoch 00024: val_loss did not improve from 0.06206
# Epoch 25/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 0.2421 - accuracy: 0.9290 - val_loss: 0.0785 - val_accuracy: 0.9841
#
# Epoch 00025: val_loss did not improve from 0.06206
# Epoch 26/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2475 - accuracy: 0.9274 - val_loss: 0.0783 - val_accuracy: 0.9809
#
# Epoch 00026: val_loss did not improve from 0.06206
# Epoch 27/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2711 - accuracy: 0.9138 - val_loss: 0.0610 - val_accuracy: 0.9841
#
# Epoch 00027: val_loss improved from 0.06206 to 0.06102, saving model to model.h5
# Epoch 28/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 0.2549 - accuracy: 0.9226 - val_loss: 0.0666 - val_accuracy: 0.9809
#
# Epoch 00028: val_loss did not improve from 0.06102
# Epoch 29/100
# 1253/1253 [==============================] - 6s 4ms/step - loss: 0.2614 - accuracy: 0.9090 - val_loss: 0.0636 - val_accuracy: 0.9873
#
# Epoch 00029: val_loss did not improve from 0.06102
# Epoch 30/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2581 - accuracy: 0.9154 - val_loss: 0.0773 - val_accuracy: 0.9873
#
# Epoch 00030: val_loss did not improve from 0.06102
# Epoch 31/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.2556 - accuracy: 0.9202 - val_loss: 0.1012 - val_accuracy: 0.9841
#
# Epoch 00031: val_loss did not improve from 0.06102
# Epoch 32/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.3213 - accuracy: 0.8978 - val_loss: 0.1275 - val_accuracy: 0.9745
#
# Epoch 00032: val_loss did not improve from 0.06102
# Epoch 33/100
# 1253/1253 [==============================] - 9s 7ms/step - loss: 0.2985 - accuracy: 0.9050 - val_loss: 0.1214 - val_accuracy: 0.9713
#
# Epoch 00033: val_loss did not improve from 0.06102
# Epoch 34/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2463 - accuracy: 0.9250 - val_loss: 0.1036 - val_accuracy: 0.9841
#
# Epoch 00034: val_loss did not improve from 0.06102
# Epoch 35/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.2381 - accuracy: 0.9234 - val_loss: 0.1119 - val_accuracy: 0.9809
#
# Epoch 00035: val_loss did not improve from 0.06102
# Epoch 36/100
# 1253/1253 [==============================] - 7s 5ms/step - loss: 0.2231 - accuracy: 0.9298 - val_loss: 0.1134 - val_accuracy: 0.9745
#
# Epoch 00036: val_loss did not improve from 0.06102
# Epoch 37/100
# 1253/1253 [==============================] - 9s 7ms/step - loss: 0.2014 - accuracy: 0.9266 - val_loss: 0.1070 - val_accuracy: 0.9841
#
# Epoch 00037: val_loss did not improve from 0.06102
# Epoch 38/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.2307 - accuracy: 0.9146 - val_loss: 0.0978 - val_accuracy: 0.9873
#
# Epoch 00038: val_loss did not improve from 0.06102
# Epoch 39/100
# 1253/1253 [==============================] - 5s 4ms/step - loss: 0.2098 - accuracy: 0.9306 - val_loss: 0.1135 - val_accuracy: 0.9841
#
# Epoch 00039: val_loss did not improve from 0.06102
# Epoch 40/100
# 1253/1253 [==============================] - 6s 5ms/step - loss: 0.2240 - accuracy: 0.9226 - val_loss: 0.0906 - val_accuracy: 0.9873
#
# Epoch 00040: val_loss did not improve from 0.06102
# Epoch 41/100
# 1253/1253 [==============================] - 8s 6ms/step - loss: 0.2167 - accuracy: 0.9298 - val_loss: 0.1156 - val_accuracy: 0.9809
#
# Epoch 00041: val_loss did not improve from 0.06102
# Epoch 42/100

# %%
model = load_model("model.h5")

# %%
print(model.test_on_batch(val_X,val_Y))
model.metrics_names
# Out:
# [0.0515158, 0.98407644]
# ['loss', 'accuracy']
